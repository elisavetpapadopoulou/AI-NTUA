# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Σεφεριάδη Δήμητρα
#
# Στοιχεία Μέλους 2: Παπαδοπούλου Ελισάβετ

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Mounted at /content/drive

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
path = '/content/drive/MyDrive/'
# Διάβασμα του αρχείου 'movie_metadata.csv'
data = pd.read_csv(path + "movies_metadata.csv")
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

column_names = {'budget':'budget', 'genres': 'genre', 'plot_keywords':'keywords', 'language':'language', 'original_title':'original_title', 'popularity':'popularity', 'production_companies':'production_company', 'production_countries':'production_country', 'release_date':'release_date', 'gross':'gross', 'duration':'duration', 'spoken_languages':'spoken_languages', 'movie_title':'movie_title', 'vote_average':'vote_average', 'title_year':'title_year', 'country':'country', 'director_name':'director', 'actor_1_name':'actor1', 'actor_2_name':'actor2', 'actor_3_name':'actor3'}

# Creates and inserts all facts for each column
def write_column(column, curfile):
    literals = []
    for row in data.itertuples(index=True, name='Pandas'):
      movie_title = clean_text(getattr(row, 'movie_title'))

      attr = clean_text(str(getattr(row,column)))
      for item in attr.split("|"):
        literals.append(column_names[column]+"('"+ movie_title +"','"+ item +"')")
    literals.sort()
    for literal in literals:
      curfile.write(literal+"."+"\n")


# Same as above but for the columns: production_companies,production_countries and spoken_languages
def write_special_column(column, curfile):
    literals = []
    for row in data.itertuples(index=True, name='Pandas'):
      movie_title = clean_text(getattr(row, 'movie_title'))

      attr = list(eval(getattr(row, column)))
      for item in attr:
        attribute = clean_text(item["name"].replace("'", ""))
        literals.append(column_names[column]+"('"+ movie_title +"','"+ attribute +"')")
    literals.sort()
    for literal in literals:
      curfile.write(literal+"."+"\n")

def write_release_year(curfile):
    literals = []
    for row in data.itertuples(index=True, name='Pandas'):
      movie_title = clean_text(getattr(row, 'movie_title'))
      attr = (getattr(row,"release_date"))
      if attr != "UNK":
        attr = attr.split("-")
        attr = attr[0]

      literals.append(column_names["release_date"]+"('"+ movie_title +"','"+ attr +"')")
    literals.sort()
    for literal in literals:
      curfile.write(literal+"."+"\n")

def writeAll():
    #This creates a file db2.pl in the current directory
    my_file = open("db2.pl", "w",encoding="utf-8")
    for column in column_names:
        if column not in ["production_companies", "production_countries","spoken_languages","release_date"]:
          write_column(column,my_file)
        elif column != 'release_date':
          write_special_column(column,my_file)
        else:
          write_release_year(my_file)
    my_file.close()

writeAll()

# %%
f = open("rules.pl", 'w')
f.write(
'''
# %Questions 1-3
five_common_genres(X,Y):-
  genre(X,N1), genre(X,N2), N1 \= N2,
  genre(Y,N1), genre(Y,N2), X \= Y,
  genre(X,N3), N1 \= N3, N2 \= N3,
  genre(Y,N3),
  genre(X,N4), N1 \= N4, N2 \= N4, N3 \= N4,
  genre(Y,N4),
  genre(X,N5), N1 \= N5, N2 \= N5,
  N3 \= N5, N4 \= N5,
  genre(Y,N5).

four_common_genres(X,Y):-
  genre(X,N1), genre(X,N2), N1 \= N2,
  genre(Y,N1), genre(Y,N2), X \= Y,
  genre(X,N3), N1 \= N3, N2 \= N3,
  genre(Y,N3), genre(X,N4),
  N1 \= N4, N2 \= N4, N3 \= N4,
  genre(Y,N4).

three_common_genres(X,Y):-
  genre(X,N1), genre(X,N2), genre(X,N3),
  N1 \= N2, N2 \= N3, N1 \= N3,
  genre(Y,N1), genre(Y,N2), genre(Y,N3),
  X \= Y.

two_common_genres(X,Y):-
  genre(X,N1), genre(X,N2),
  N1 \= N2,
  genre(Y,N1), genre(Y,N2),
  X \= Y.

one_common_genre(X,Y):-genre(X,N), genre(Y,N), X \= Y.

# %Question 4
common_director(X,Y):-director(X,N), director(Y,N), X \= Y.

# %Questions 5-6
same_plot(X,Y):-
  keywords(X,N1), keywords(X,N2), N1 \= N2,
  keywords(Y,N1), keywords(Y,N2), X \= Y,
  keywords(X,N3), N1 \= N3, N2 \= N3,
  keywords(Y,N3),
  keywords(X,N4), N1 \= N4, N2 \= N4, N3 \= N4,
  keywords(Y,N4),
  keywords(X,N5), N1 \= N5,N2 \= N5,
  N3 \= N5, N4 \= N5,
  keywords(Y,N5).

four_keywords(X,Y):-
  keywords(X,N1), keywords(X,N2), N1 \= N2,
  keywords(Y,N1), keywords(Y,N2), X \= Y,
  keywords(X,N3), N1 \= N3, N2 \= N3,
  keywords(Y,N3),
  keywords(X,N4), N1 \= N4, N2 \= N4, N3 \= N4,
  keywords(Y,N4).

three_keywords(X,Y):-
  keywords(X,N1), keywords(X,N2),
  N1 \= N2,
  keywords(Y,N1), keywords(Y,N1),
  X \= Y, keywords(X,N3),
  N1 \= N3, N2 \= N3,
  keywords(Y,N3).

similar_plot(X,Y):-
  keywords(X,N1), keywords(X,N2),
  N1 \= N2,
  keywords(Y,N1), keywords(Y,N1),
  X \= Y.

one_keyword(X,Y):-keywords(X,N), keywords(Y,N), X \= Y.

# %Question 7-9
actor(X,N):-actor1(X,N).
actor(X,N):-actor2(X,N).
actor(X,N):-actor3(X,N).

same_actors(X,Y):-
  actor(X,N1), actor(X,N2), actor(X,N3),
  N1 \= N2, N1 \= N3, N2 \= N3,
  actor(Y,N1), actor(Y,N2), actor(Y,N3),
  X \= Y.

similar_actors(X,Y):-
  actor(X,N1), actor(X,N2), N1 \= N2,
  actor(Y,N1), actor(Y,N2), X \= Y.

one_common_actor(X,Y):-actor(X,N), actor(Y,N), X \= Y.

# %Question 10
same_language(X,Y):-language(X,N), language(Y,N), X \= Y.

# %Question 11
black_and_white(X):-keywords(X,'black and white').

# %Question 12
common_company(X,Y):-
  production_company(X,N),
  production_company(Y,N),
  X \= Y.

# %Question 13
common_country(X,Y):-
  production_country(X,N),
  production_country(Y,N),
  x \= Y.

# %Question 14
common_decade(X,Y):-
  release_date(X,N),
  release_date(Y,N),
  x \= Y.

'''
)
f.close()

# %% [markdown]
# Επίδειξη λειτουργίας μέρους 1

# %%
prolog = Prolog()
prolog.consult("db2.pl")
prolog.consult("rules.pl")

sample_movies = ['Avatar', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'The Avengers', 'The Hobbit: The Battle of the Five Armies', 'Toy Story 3', 'Interstellar', 'Inception', 'The Fast and the Furious', 'Madagascar: Escape 2 Africa', 'How the Grinch Stole Christmas', 'I, Robot', 'A.I. Artificial Intelligence', 'Looney Tunes: Back in Action']
sample_queries = ['five_common_genres', 'two_common_genres', 'common_director', 'same_plot', 'similar_plot', 'similar_actors', 'common_company', 'common_decade']

for movie in sample_movies:
  print ("Movie: " + movie)
  for query in sample_queries:
    q = prolog.query(query + "('" + movie + "',M)")
    print("Query: " + query)
    s = set()
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
    q.close()
    print("We have " + str(len(s)) + " movies")
    print("Some of them are: " + str(list(s)[:10]))
    answers = s
# Out:
# Movie: Avatar
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 806 movies
# Some of them are: ['Enders Game', 'Lethal Weapon 3', 'Kate & Leopold', 'Caravans', 'Vertical Limit', 'Executive Decision', 'Lucy', 'The Hole', 'Conan the Barbarian', 'The Negotiator']
# Query: common_director
# We have 6 movies
# Some of them are: ['Terminator 2: Judgment Day', 'Titanic', 'The Terminator', 'The Abyss', 'Aliens', 'True Lies']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 354 movies
# Some of them are: ['Bait', 'East Is East', 'Enders Game', 'Lucy', 'Monsters vs Aliens', 'High Noon', 'Lions for Lambs', 'Ravenous', 'Dune', 'The Four Feathers']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 265 movies
# Some of them are: ['Eragon', 'Rise of the Planet of the Apes', 'Prometheus', 'History of the World: Part I', 'Gullivers Travels', 'Percy Jackson: Sea of Monsters', 'Behind Enemy Lines', 'Garfield: A Tail of Two Kitties', 'Big', 'Chain Reaction']
# Query: common_decade
# We have 247 movies
# Some of them are: ['Agora', 'Janky Promoters', 'Knowing', 'Soul Kitchen', 'Motherhood', 'Bran Nue Dae', 'The Hole', 'Crying with Laughter', 'Dogtooth', 'Monsters vs Aliens']
# Movie: Harry Potter and the Half-Blood Prince
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 373 movies
# Some of them are: ['The Hole', 'Conan the Barbarian', 'Monsters vs Aliens', 'Flipper', 'Big', 'Mr. Peabody & Sherman', 'Osmosis Jones', 'The Nutcracker', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'How the Grinch Stole Christmas']
# Query: common_director
# We have 2 movies
# Some of them are: ['The Legend of Tarzan', 'Harry Potter and the Order of the Phoenix']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 113 movies
# Some of them are: ['The Crying Game', 'Mary Poppins', 'The Immigrant', 'Harry Potter and the Goblet of Fire', 'Hansel and Gretel Get Baked', 'Cinderella', 'Hotel Transylvania', 'Book of Shadows: Blair Witch 2', 'Wolves', 'Warcraft']
# Query: similar_actors
# We have 5 movies
# Some of them are: ['Harry Potter and the Goblet of Fire', 'Harry Potter and the Chamber of Secrets', 'Harry Potter and the Prisoner of Azkaban', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Philosophers Stone']
# Query: common_company
# We have 322 movies
# Some of them are: ['Lethal Weapon 3', 'Grudge Match', 'Executive Decision', 'Tin Cup', 'The Negotiator', 'The Whole Nine Yards', 'Malibus Most Wanted', 'Ravenous', 'Osmosis Jones', 'Watchmen']
# Query: common_decade
# We have 247 movies
# Some of them are: ['Agora', 'Janky Promoters', 'Knowing', 'Soul Kitchen', 'Motherhood', 'Bran Nue Dae', 'The Hole', 'Crying with Laughter', 'Dogtooth', 'Monsters vs Aliens']
# Movie: Batman v Superman: Dawn of Justice
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 616 movies
# Some of them are: ['Enders Game', 'Lethal Weapon 3', 'Caravans', 'Vertical Limit', 'Executive Decision', 'The Hole', 'Conan the Barbarian', 'The Negotiator', 'Star Trek: Insurrection', 'Baahubali: The Beginning']
# Query: common_director
# We have 6 movies
# Some of them are: ['Sucker Punch', 'Legend of the Guardians: The Owls of GaHoole', 'Watchmen', '300', 'Man of Steel', 'Dawn of the Dead']
# Query: same_plot
# We have 3 movies
# Some of them are: ['Batman Begins', 'The Dark Knight', 'Man of Steel']
# Query: similar_plot
# We have 213 movies
# Some of them are: ['Irreversible', 'Class of 1984', 'Road House', 'Nothing to Lose', 'Prisoners', 'Mystery Men', 'Nurse 3-D', 'Warcraft', 'The Toxic Avenger Part II', 'Creepshow 2']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 336 movies
# Some of them are: ['Lethal Weapon 3', 'Grudge Match', 'Executive Decision', 'Tin Cup', 'The Negotiator', 'The Whole Nine Yards', 'Malibus Most Wanted', 'Osmosis Jones', 'Watchmen', 'Midnight Special']
# Query: common_decade
# We have 104 movies
# Some of them are: ['Fight to the Finish', 'Warcraft', 'Compadres', 'The Secret Life of Pets', 'Alleluia! The Devils Carnival', 'Money Monster', 'Allegiant', 'Fight Valley', 'Central Intelligence', 'I Am Wrath']
# Movie: The Avengers
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 650 movies
# Some of them are: ['Enders Game', 'Lethal Weapon 3', 'Caravans', 'Vertical Limit', 'Executive Decision', 'Lucy', 'Conan the Barbarian', 'The Negotiator', 'Star Trek: Insurrection', 'Monsters vs Aliens']
# Query: common_director
# We have 2 movies
# Some of them are: ['Serenity', 'Avengers: Age of Ultron']
# Query: same_plot
# We have 13 movies
# Some of them are: ['X-Men: Apocalypse', 'Iron Man 2', 'Iron Man 3', 'Captain America: The Winter Soldier', 'Captain America: The First Avenger', 'Iron Man', 'Thor', 'The Incredible Hulk', 'Deadpool', 'Captain America: Civil War']
# Query: similar_plot
# We have 567 movies
# Some of them are: ['Lethal Weapon 3', 'Enders Game', 'Ta Ra Rum Pum', 'The Immigrant', 'Clerks', 'Monsters vs Aliens', 'Live and Let Die', 'Bridget Joness Diary', 'Changing Lanes', 'Mr. Peabody & Sherman']
# Query: similar_actors
# We have 1 movies
# Some of them are: ['Avengers: Age of Ultron']
# Query: common_company
# We have 296 movies
# Some of them are: ['The Firm', 'Willy Wonka & the Chocolate Factory', 'Indiana Jones and the Kingdom of the Crystal Skull', 'Æon Flux', 'Lara Croft: Tomb Raider', 'Hercules', 'Crocodile Dundee', 'A Simple Plan', 'Beverly Hills Cop', 'Escape from L.A.']
# Query: common_decade
# We have 208 movies
# Some of them are: ['Bait', 'Restless', 'The Grey', 'Atlas Shrugged Part II', 'Madeas Witness Protection', 'Prometheus', 'Fly Me to the Moon', 'Safe House', 'The Possession', 'Hotel Transylvania']
# Movie: The Hobbit: The Battle of the Five Armies
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 616 movies
# Some of them are: ['Enders Game', 'Lethal Weapon 3', 'Caravans', 'Vertical Limit', 'Executive Decision', 'The Hole', 'Conan the Barbarian', 'The Negotiator', 'Star Trek: Insurrection', 'Baahubali: The Beginning']
# Query: common_director
# We have 8 movies
# Some of them are: ['The Lord of the Rings: The Return of the King', 'Heavenly Creatures', 'The Lovely Bones', 'The Hobbit: The Desolation of Smaug', 'The Lord of the Rings: The Two Towers', 'The Lord of the Rings: The Fellowship of the Ring', 'King Kong', 'The Hobbit: An Unexpected Journey']
# Query: same_plot
# We have 4 movies
# Some of them are: ['The Lord of the Rings: The Two Towers', 'The Lord of the Rings: The Fellowship of the Ring', 'The Hobbit: The Desolation of Smaug', 'The Hobbit: An Unexpected Journey']
# Query: similar_plot
# We have 121 movies
# Some of them are: ['Eragon', 'The Immigrant', 'Casablanca', 'Dungeons & Dragons: Wrath of the Dragon God', 'Hercules', 'Nothing to Lose', 'L.A. Confidential', 'The Negotiator', 'Conan the Barbarian', 'Warcraft']
# Query: similar_actors
# We have 1 movies
# Some of them are: ['The Hobbit: The Desolation of Smaug']
# Query: common_company
# We have 288 movies
# Some of them are: ['A Nightmare on Elm Street Part 2: Freddys Revenge', 'Menace II Society', 'Dumb and Dumber', 'Teenage Mutant Ninja Turtles III', 'Hercules', 'Cats Dont Dance', 'Get Shorty', 'Pat Garrett & Billy the Kid', 'Rock of Ages', 'I Am Sam']
# Query: common_decade
# We have 238 movies
# Some of them are: ['Ride Along', 'Pompeii', 'Heaven is for Real', 'Housebound', 'Hercules', 'Not Cool', 'Coming Home', 'Lucy', 'St. Vincent', 'And So It Goes']
# Movie: Toy Story 3
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 396 movies
# Some of them are: ['Ta Ra Rum Pum', 'The Pacifier', 'Monsters vs Aliens', 'The Shaggy Dog', 'Anomalisa', 'Big', 'Mr. Peabody & Sherman', 'Osmosis Jones', 'The Rugrats Movie', 'Happy Feet']
# Query: common_director
# We have 0 movies
# Some of them are: []
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 458 movies
# Some of them are: ['The Immigrant', 'Executive Decision', 'The Negotiator', 'Monsters vs Aliens', 'Bridget Joness Diary', 'Mr. Peabody & Sherman', 'Nine', 'Street Fighter', 'Feast', 'Happy Feet']
# Query: similar_actors
# We have 1 movies
# Some of them are: ['Toy Story 2']
# Query: common_company
# We have 117 movies
# Some of them are: ['The Adventures of Huck Finn', 'Cinderella', 'The Pacifier', 'The Emperors New Groove', 'The Shaggy Dog', 'Maleficent', 'The Santa Clause', 'The Kid', 'The Incredibles', 'Bedtime Stories']
# Query: common_decade
# We have 225 movies
# Some of them are: ['RED', 'Gullivers Travels', 'Death Calls', 'Burlesque', 'Eat Pray Love', 'Good Intentions', 'Animals United', 'Why Did I Get Married Too?', 'Our Family Wedding', 'Space Battleship Yamato']
# Movie: Interstellar
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 460 movies
# Some of them are: ['Enders Game', 'Caravans', 'Executive Decision', 'The Negotiator', 'Star Trek: Insurrection', 'Monsters vs Aliens', 'Timeline', 'Robot & Frank', 'Lions for Lambs', 'Dune']
# Query: common_director
# We have 7 movies
# Some of them are: ['Batman Begins', 'The Dark Knight', 'Inception', 'Insomnia', 'Memento', 'The Prestige', 'The Dark Knight Rises']
# Query: same_plot
# We have 2 movies
# Some of them are: ['Silent Running', 'Apollo 13']
# Query: similar_plot
# We have 457 movies
# Some of them are: ['East Is East', 'Enders Game', 'Ta Ra Rum Pum', 'Grudge Match', 'Lucy', 'Executive Decision', 'The Pacifier', 'The Shaggy Dog', 'Timeline', 'Mr. Peabody & Sherman']
# Query: similar_actors
# We have 1 movies
# Some of them are: ['The Dark Knight Rises']
# Query: common_company
# We have 611 movies
# Some of them are: ['Lethal Weapon 3', 'Grudge Match', 'Executive Decision', 'Tin Cup', 'The Negotiator', 'Star Trek: Insurrection', 'The Whole Nine Yards', 'Timeline', 'Changing Lanes', 'Black Rain']
# Query: common_decade
# We have 238 movies
# Some of them are: ['Ride Along', 'Pompeii', 'Heaven is for Real', 'Housebound', 'Hercules', 'Not Cool', 'Coming Home', 'Lucy', 'St. Vincent', 'And So It Goes']
# Movie: Inception
# Query: five_common_genres
# We have 4 movies
# Some of them are: ['Congo', 'Sky Captain and the World of Tomorrow', 'Paycheck', 'Knowing']
# Query: two_common_genres
# We have 1236 movies
# Some of them are: ['Bait', 'Enders Game', 'Irreversible', 'Vertical Limit', 'The Hole', 'The Pacifier', 'Conan the Barbarian', 'The Protector', 'Monsters vs Aliens', 'Baahubali: The Beginning']
# Query: common_director
# We have 7 movies
# Some of them are: ['Batman Begins', 'The Dark Knight', 'Interstellar', 'Insomnia', 'Memento', 'The Prestige', 'The Dark Knight Rises']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 134 movies
# Some of them are: ['Fast Five', 'Abduction', 'The Way of the Gun', 'Crying with Laughter', 'Frailty', 'Prisoners', 'A Lonely Place to Die', 'The Call', 'Show Me', 'Untraceable']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 330 movies
# Some of them are: ['Lethal Weapon 3', 'Grudge Match', 'Executive Decision', 'Tin Cup', 'The Negotiator', 'The Whole Nine Yards', 'Malibus Most Wanted', 'Osmosis Jones', 'Watchmen', 'Midnight Special']
# Query: common_decade
# We have 225 movies
# Some of them are: ['RED', 'Gullivers Travels', 'Death Calls', 'Burlesque', 'Eat Pray Love', 'Good Intentions', 'Animals United', 'Why Did I Get Married Too?', 'Our Family Wedding', 'Space Battleship Yamato']
# Movie: The Fast and the Furious
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 871 movies
# Some of them are: ['Bait', 'Lethal Weapon 3', 'Irreversible', 'Class of 1984', 'Safe House', 'The Skulls', 'Vertical Limit', 'Stone Cold', 'Executive Decision', 'Road House']
# Query: common_director
# We have 8 movies
# Some of them are: ['The Mummy: Tomb of the Dragon Emperor', 'Daylight', 'The Skulls', 'The Boy Next Door', 'DragonHeart', 'xXx', 'Stealth', 'Alex Cross']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 548 movies
# Some of them are: ['Lethal Weapon 3', 'Clerks', 'Stone Cold', 'Monsters vs Aliens', 'Live and Let Die', 'Bridget Joness Diary', 'Malibus Most Wanted', 'Mr. Peabody & Sherman', 'Paranormal Activity 4', 'The Rugrats Movie']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 332 movies
# Some of them are: ['The Skulls', 'Safe House', 'Trainwreck', 'Caravans', 'Lucy', 'Conan the Barbarian', 'Vantage Point', 'The Watcher', 'Bridget Joness Diary', 'Flipper']
# Query: common_decade
# We have 183 movies
# Some of them are: ['Kate & Leopold', 'Hearts in Atlantis', 'The Cavemans Valentine', 'Lara Croft: Tomb Raider', 'Wasabi', 'Joy Ride', 'Lovely & Amazing', 'Frailty', 'Captain Corellis Mandolin', 'Behind Enemy Lines']
# Movie: Madagascar: Escape 2 Africa
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 194 movies
# Some of them are: ['Cats Dont Dance', 'The Lion of Judah', 'Stuart Little', 'Hotel Transylvania', 'Alvin and the Chipmunks: The Road Chip', 'The Emperors New Groove', 'Monsters vs Aliens', 'The Prince of Egypt', 'Garfield: A Tail of Two Kitties', 'Mr. Peabody & Sherman']
# Query: common_director
# We have 3 movies
# Some of them are: ['Penguins of Madagascar', 'Madagascar', 'Antz']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 556 movies
# Some of them are: ['East Is East', 'Bait', 'Executive Decision', 'Lucy', 'Monsters vs Aliens', 'Flightplan', 'Bridget Joness Diary', 'Mr. Peabody & Sherman', 'The Toxic Avenger Part II', 'Nine']
# Query: similar_actors
# We have 1 movies
# Some of them are: ['Madagascar']
# Query: common_company
# We have 30 movies
# Some of them are: ['Shrek', 'Spirit: Stallion of the Cimarron', 'The Road to El Dorado', 'Madagascar 3: Europes Most Wanted', 'The Curse of the Were-Rabbit', 'Shrek 2', 'The Prince of Egypt', 'Monsters vs Aliens', 'Kung Fu Panda', 'The Croods']
# Query: common_decade
# We have 227 movies
# Some of them are: ['Indiana Jones and the Kingdom of the Crystal Skull', 'The Brothers Bloom', 'The Other End of the Line', 'The Duchess', 'The Poker House', 'Eagle Eye', 'Be Kind Rewind', 'Vantage Point', 'Bottle Shock', 'Rachel Getting Married']
# Movie: How the Grinch Stole Christmas
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 445 movies
# Some of them are: ['Kate & Leopold', 'Ta Ra Rum Pum', 'The Pacifier', 'The Shaggy Dog', 'Big', 'Osmosis Jones', 'The Nutcracker', 'R.I.P.D.', 'Daddy Day Camp', 'Air Bud']
# Query: common_director
# We have 12 movies
# Some of them are: ['A Beautiful Mind', 'Ransom', 'Apollo 13', 'Rush', 'The Da Vinci Code', 'Edtv', 'Frost/Nixon', 'In the Heart of the Sea', 'Cinderella Man', 'Angels & Demons']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 116 movies
# Some of them are: ['Agora', 'Stuart Little', 'Road House', 'Bruce Almighty', 'The Apartment', 'Bridget Joness Diary', 'A Mighty Heart', 'Proof of Life', 'The Santa Clause', 'The Karate Kid']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 325 movies
# Some of them are: ['The Skulls', 'Safe House', 'Trainwreck', 'Caravans', 'Take Me Home Tonight', 'Lucy', 'Conan the Barbarian', 'Flightplan', 'The Watcher', 'Bridget Joness Diary']
# Query: common_decade
# We have 166 movies
# Some of them are: ['The Skulls', 'Road Trip', 'Charlies Angels', 'Red Planet', 'The Broken Hearts Club: A Romantic Comedy', 'Vertical Limit', 'The Way of the Gun', 'Lisa Picard Is Famous', 'Book of Shadows: Blair Witch 2', 'The Emperors New Groove']
# Movie: I, Robot
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 277 movies
# Some of them are: ['Enders Game', 'Dragon Wars: D-War', 'Rise of the Planet of the Apes', 'Equilibrium', 'Small Soldiers', 'Knowing', 'Red Planet', 'Teenage Mutant Ninja Turtles III', 'The Host', 'Æon Flux']
# Query: common_director
# We have 4 movies
# Some of them are: ['The Crow', 'Dark City', 'Gods of Egypt', 'Knowing']
# Query: same_plot
# We have 2 movies
# Some of them are: ['The Matrix Revolutions', 'The Matrix Reloaded']
# Query: similar_plot
# We have 747 movies
# Some of them are: ['Bait', 'Enders Game', 'Irreversible', 'Class of 1984', 'The Immigrant', 'Lucy', 'The Negotiator', 'Finding Forrester', 'The Call', 'Halloween']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 251 movies
# Some of them are: ['Eragon', 'The Firm', 'Rise of the Planet of the Apes', 'Prometheus', 'History of the World: Part I', 'Gullivers Travels', 'Behind Enemy Lines', 'Finding Forrester', 'Garfield: A Tail of Two Kitties', 'Big']
# Query: common_decade
# We have 204 movies
# Some of them are: ['Catch That Kid', 'The Merchant of Venice', 'Proud', 'The Aviator', '50 First Dates', 'Show Me', 'Riding Giants', 'The Grudge', 'Jersey Girl', 'The Incredibles']
# Movie: A.I. Artificial Intelligence
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 460 movies
# Some of them are: ['Enders Game', 'Caravans', 'Executive Decision', 'The Negotiator', 'Star Trek: Insurrection', 'Monsters vs Aliens', 'Timeline', 'Robot & Frank', 'Lions for Lambs', 'Dune']
# Query: common_director
# We have 26 movies
# Some of them are: ['Raiders of the Lost Ark', 'Indiana Jones and the Kingdom of the Crystal Skull', 'Hook', 'Jurassic Park', 'Minority Report', 'The Color Purple', 'Amistad', 'The BFG', 'Schindlers List', 'Indiana Jones and the Last Crusade']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 353 movies
# Some of them are: ['Irreversible', 'Lucy', 'Wolves', 'Monsters vs Aliens', 'Mr. Peabody & Sherman', 'Dune', 'Babylon A.D.', 'Signs', 'Shrek the Third', 'October Baby']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 423 movies
# Some of them are: ['Lethal Weapon 3', 'Grudge Match', 'Executive Decision', 'Tin Cup', 'The Negotiator', 'The Whole Nine Yards', 'Malibus Most Wanted', 'Osmosis Jones', 'The Lovely Bones', 'Delivery Man']
# Query: common_decade
# We have 183 movies
# Some of them are: ['Kate & Leopold', 'Hearts in Atlantis', 'The Cavemans Valentine', 'Lara Croft: Tomb Raider', 'Wasabi', 'Joy Ride', 'Lovely & Amazing', 'Frailty', 'Captain Corellis Mandolin', 'Behind Enemy Lines']
# Movie: Looney Tunes: Back in Action
# Query: five_common_genres
# We have 0 movies
# Some of them are: []
# Query: two_common_genres
# We have 396 movies
# Some of them are: ['Ta Ra Rum Pum', 'The Pacifier', 'Monsters vs Aliens', 'The Shaggy Dog', 'Anomalisa', 'Big', 'Mr. Peabody & Sherman', 'Osmosis Jones', 'The Rugrats Movie', 'Happy Feet']
# Query: common_director
# We have 5 movies
# Some of them are: ['The Howling', 'Small Soldiers', 'Gremlins 2: The New Batch', 'The Hole', 'Gremlins']
# Query: same_plot
# We have 0 movies
# Some of them are: []
# Query: similar_plot
# We have 59 movies
# Some of them are: ['Restless', 'Diamonds Are Forever', 'Never Say Never Again', 'Mary Poppins', 'The Living Daylights', 'Petes Dragon', 'Casablanca', 'The Legend of Zorro', 'The Hunting Party', 'Tomorrow Never Dies']
# Query: similar_actors
# We have 0 movies
# Some of them are: []
# Query: common_company
# We have 326 movies
# Some of them are: ['Lethal Weapon 3', 'Grudge Match', 'Executive Decision', 'Tin Cup', 'The Negotiator', 'The Whole Nine Yards', 'Malibus Most Wanted', 'Osmosis Jones', 'Watchmen', 'Midnight Special']
# Query: common_decade
# We have 169 movies
# Some of them are: ['The Cat in the Hat', 'Shattered Glass', 'Under the Tuscan Sun', '11:14', 'Charlies Angels: Full Throttle', 'Osama', 'Radio', '2 Fast 2 Furious', 'The Flower of Evil', 'Wrong Turn']

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
f = open("recommender.pl", 'w')
f.write(
'''
find_sim_1(X,Y):-four_common_genres(X,Y).
find_sim_1(X,Y):-similar_plot(X,Y).
find_sim_1(X,Y):-one_common_actor(X,Y).
find_sim_1(X,Y):-same_language(X,Y).
find_sim_1(X,Y):-common_decade(X,Y).
find_sim_1(X,Y):-common_country(X,Y).
find_sim_1(X,Y):-common_company(X,Y).


find_sim_2(X,Y):-three_common_genres(X,Y).
find_sim_2(X,Y):-three_keywords(X,Y).
find_sim_2(X,Y):-similar_actors(X,Y).
find_sim_2(X,Y):-same_language(X,Y).
find_sim_2(X,Y):-common_decade(X,Y).

find_sim_3(X,Y):-four_common_genres(X,Y).
find_sim_3(X,Y):-four_keywords(X,Y).
find_sim_3(X,Y):-same_actors(X,Y).
find_sim_3(X,Y):-common_decade(X,Y).

find_sim_4(X,Y):-five_common_genres(X,Y).
find_sim_4(X,Y):-same_plot(X,Y).
find_sim_4(X,Y):-same_actors(X,Y).
find_sim_4(X,Y):-common_decade(X,Y).

find_sim_5(X,Y):-five_common_genres(X,Y).
find_sim_5(X,Y):-same_plot(X,Y).
find_sim_5(X,Y):-same_actors(X,Y).
find_sim_5(X,Y):-common_director(X,Y).
find_sim_5(X,Y):-black_and_white(X), black_and_white(Y), X\=Y.

'''
)
f.close()

# %%
def simple_recommender(movie, precision=1):
    prolog = Prolog()
    prolog.consult("db2.pl")
    prolog.consult("rules.pl")
    prolog.consult("recommender.pl")

    s = set()
    q = prolog.query("find_sim_" + str(precision) + "('"+ movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
    q.close()
    answers = s
    return answers

# %%
list(simple_recommender('Avatar'))[:5]
# Out:
# ['Bait', 'East Is East', 'Enders Game', 'The Immigrant', 'Sisters in Law']

# %% [markdown]
# Επίδειξη λειτουργίας μέρους 2

# %%
sample_movies = ['Avatar', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'The Avengers', 'The Hobbit: The Battle of the Five Armies', 'Toy Story 3', 'Interstellar', 'Inception', 'The Fast and the Furious', 'Madagascar: Escape 2 Africa', 'How the Grinch Stole Christmas', 'I, Robot', 'A.I. Artificial Intelligence', 'Looney Tunes: Back in Action']

for movie in sample_movies:
  print ("Movie: " + movie)
  for i in range(1,6):
    print("Precision: " + str(i))
    recommender = list(simple_recommender(movie, i))
    print("We have " + str(len(recommender)) + " similar movies")
    print("Some of them are: " + str(recommender)[:5])
# Out:
# Movie: Avatar
# Precision: 1
# We have 4519 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4165 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 273 similar movies
# Some of them are: ['Ago
# Precision: 4
# We have 247 similar movies
# Some of them are: ['Ago
# Precision: 5
# We have 6 similar movies
# Some of them are: ['Ter
# Movie: Harry Potter and the Half-Blood Prince
# Precision: 1
# We have 4510 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4150 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 250 similar movies
# Some of them are: ['Ago
# Precision: 4
# We have 247 similar movies
# Some of them are: ['Ago
# Precision: 5
# We have 2 similar movies
# Some of them are: ['The
# Movie: Batman v Superman: Dawn of Justice
# Precision: 1
# We have 4458 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4121 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 112 similar movies
# Some of them are: ['Fig
# Precision: 4
# We have 107 similar movies
# Some of them are: ['Fig
# Precision: 5
# We have 8 similar movies
# Some of them are: ['Bat
# Movie: The Avengers
# Precision: 1
# We have 4471 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4142 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 226 similar movies
# Some of them are: ['Bai
# Precision: 4
# We have 221 similar movies
# Some of them are: ['Bai
# Precision: 5
# We have 14 similar movies
# Some of them are: ['X-M
# Movie: The Hobbit: The Battle of the Five Armies
# Precision: 1
# We have 4473 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4146 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 243 similar movies
# Some of them are: ['Rid
# Precision: 4
# We have 242 similar movies
# Some of them are: ['Rid
# Precision: 5
# We have 8 similar movies
# Some of them are: ['The
# Movie: Toy Story 3
# Precision: 1
# We have 4480 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4139 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 226 similar movies
# Some of them are: ['RED
# Precision: 4
# We have 225 similar movies
# Some of them are: ['RED
# Precision: 5
# We have 0 similar movies
# Some of them are: []
# Movie: Interstellar
# Precision: 1
# We have 4526 similar movies
# Some of them are: ['Eas
# Precision: 2
# We have 4150 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 244 similar movies
# Some of them are: ['Rid
# Precision: 4
# We have 240 similar movies
# Some of them are: ['Rid
# Precision: 5
# We have 9 similar movies
# Some of them are: ['Bat
# Movie: Inception
# Precision: 1
# We have 4505 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4179 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 296 similar movies
# Some of them are: ['Kno
# Precision: 4
# We have 229 similar movies
# Some of them are: ['Kno
# Precision: 5
# We have 11 similar movies
# Some of them are: ['Sky
# Movie: The Fast and the Furious
# Precision: 1
# We have 4500 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4154 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 186 similar movies
# Some of them are: ['Kat
# Precision: 4
# We have 183 similar movies
# Some of them are: ['Kat
# Precision: 5
# We have 8 similar movies
# Some of them are: ['The
# Movie: Madagascar: Escape 2 Africa
# Precision: 1
# We have 4480 similar movies
# Some of them are: ['Eas
# Precision: 2
# We have 4147 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 228 similar movies
# Some of them are: ['Ind
# Precision: 4
# We have 228 similar movies
# Some of them are: ['Ind
# Precision: 5
# We have 3 similar movies
# Some of them are: ['Pen
# Movie: How the Grinch Stole Christmas
# Precision: 1
# We have 4499 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4129 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 166 similar movies
# Some of them are: ['The
# Precision: 4
# We have 166 similar movies
# Some of them are: ['The
# Precision: 5
# We have 12 similar movies
# Some of them are: ['A B
# Movie: I, Robot
# Precision: 1
# We have 4527 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4159 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 211 similar movies
# Some of them are: ['Cat
# Precision: 4
# We have 206 similar movies
# Some of them are: ['Cat
# Precision: 5
# We have 6 similar movies
# Some of them are: ['The
# Movie: A.I. Artificial Intelligence
# Precision: 1
# We have 4470 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4135 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 183 similar movies
# Some of them are: ['Kat
# Precision: 4
# We have 183 similar movies
# Some of them are: ['Kat
# Precision: 5
# We have 26 similar movies
# Some of them are: ['Rai
# Movie: Looney Tunes: Back in Action
# Precision: 1
# We have 4499 similar movies
# Some of them are: ['Bai
# Precision: 2
# We have 4137 similar movies
# Some of them are: ['Bai
# Precision: 3
# We have 169 similar movies
# Some of them are: ['The
# Precision: 4
# We have 169 similar movies
# Some of them are: ['The
# Precision: 5
# We have 5 similar movies
# Some of them are: ['The

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
#score_weights = {i:i + 1 for i in range(1)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender
score_weights = {1:0.05, 2:0.5, 3:2, 4:5, 5:10}
def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        #similar_movies = simple_recommender(movie)
        done_movies = set()

        for precision in range(5,0,-1):
          similar_movies = simple_recommender(movie, precision)
          for similar_movie in similar_movies:
            if similar_movie in done_movies:
              continue
            else:
              done_movies.add(similar_movie)
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[precision]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[precision] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Οι παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 3)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.4635265549872861
# recall: 0.6972222222222223
# f1: 0.4992732158398553

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 5)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.45911375002395705
# recall: 0.8402777777777779
# f1: 0.5934085037848378

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5080951092310799
# recall: 0.8361111111111112
# f1: 0.6043192541419851

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5017120213108226
# recall: 0.8430555555555556
# f1: 0.6074228813597128

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 50)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")

# %% [markdown]
# **Παρατηρήσεις**
#
# Ο αλγόριθμος μας δεν τα πηγαίνει πολύ καλά για λίγες ταινίες, δηλαδή για 3 ή 5 ταινίες και στη συνέχεια το σκορ βελτιώνεται αισθητά για περισσότερες ταινίες, το δοκιμάσαμε για τις τιμές 10, 30 και 50. Επομένως, ενδείκνυται για ένα σύστημα συστάσεων για παλιούς χρήστες όπου δεδομένου ικανοποιητικού αριθμού ταινιών ο αλγόριθμος είναι σε θέση να προτείνει καλές συστάσεις, αλλά δεν ενδείκνυται τόσο για νέους χρήστες με λίγες αξιολόγησεις.
#
# Αυτό που αλλάξαμε στον ήδη υπάρχον αλγόριθμο είναι ότι τώρα χρησιμοποιέι μία μεταβλητή precision η οποία μας δείχνει ποια find_sim χρησιμοποιούμε και λαμβάνοντας αυτήν υπόψη τα score_weights μας αλλάζουν ανάλογα με την ομοίότητα των ταινιών.
